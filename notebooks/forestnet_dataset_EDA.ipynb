# %%
import geopandas as gpd
import numpy as np

# %%
path = '/Users/janpisl/Documents/EPFL/drivers/data/forestnet/forestnet.shp'

# %%
gdf = gpd.read_file(path)
gdf.head()
# Out:
#                            label               merged_lab  latitude  \
# 0              Timber plantation               Plantation  4.430849
# 1                          Other                    Other  1.332341
# 2            Grassland shrubland      Grassland shrubland -1.720266
# 3        Small-scale agriculture  Smallholder agriculture -2.248346
# 4  Other large-scale plantations               Plantation -2.100800
#
#     longitude  year                                       example_pa  \
# 0   96.101634  2014      examples/4.430849118860583_96.1016343478138
# 1  109.374229  2012   examples/1.3323406178609702_109.37422873130464
# 2  115.006996  2016  examples/-1.7202663845775041_115.00699582064483
# 3  104.135786  2011    examples/-2.248346072674411_104.1357857482906
# 4  113.022376  2008   examples/-2.100800102991412_113.02237632340159
#
#                      geometry
# 0    POINT (96.10163 4.43085)
# 1   POINT (109.37423 1.33234)
# 2  POINT (115.00700 -1.72027)
# ...

# %%
np.unique(gdf.label, return_counts=True)
# Out:
# (array(['Fish pond', 'Grassland shrubland', 'Logging', 'Mining',
#         'Oil palm plantation', 'Other', 'Other large-scale plantations',
#         'Secondary forest', 'Small-scale agriculture',
#         'Small-scale mixed plantation', 'Small-scale oil palm plantation',
#         'Timber plantation'], dtype=object),
#  array([ 24, 143,  39,  48, 337,  49, 118,  71, 355, 119,  82, 231]))

# %%
np.unique(gdf.latitude).shape
# Out:
# (1616,)

# %%
gdf
# Out:
#                               label               merged_lab  latitude  \
# 0                 Timber plantation               Plantation  4.430849
# 1                             Other                    Other  1.332341
# 2               Grassland shrubland      Grassland shrubland -1.720266
# 3           Small-scale agriculture  Smallholder agriculture -2.248346
# 4     Other large-scale plantations               Plantation -2.100800
# ...                             ...                      ...       ...
# 1611            Oil palm plantation               Plantation  1.449926
# 1612   Small-scale mixed plantation  Smallholder agriculture -0.627725
# 1613            Oil palm plantation               Plantation -0.156806
# 1614              Timber plantation               Plantation -0.684267
# 1615        Small-scale agriculture  Smallholder agriculture -3.262701
#
#        longitude  year                                       example_pa  \
# ...
